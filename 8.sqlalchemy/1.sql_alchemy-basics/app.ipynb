# %% [markdown]
# ### Purpose: entry point of the app.
#
#     - Imports engine & SessionLocal from db/config.py.
#     - Imports models (so SQLAlchemy knows about them).
#     - Calls Base.metadata.create_all() to create tables.
#     - Runs a simple CRUD test.

# %%
## Imports

from sqlalchemy import or_, and_, select  # Importing SQLAlchemy functions for complex queries.
from db.config import engine, SessionLocal  # Brings in the engine (connection to the database) and SessionLocal (our session factory for talking to DB).
from db.base import Base  # Imports the Base class. This holds all models’ metadata (like table definitions).
from models.user import User
from models.post import Post
from models.profile import Profile
import models.like  # Import the like association table to ensure it's registered in metadata.

# %%
Base.metadata.drop_all(bind=engine)

Base.metadata.create_all(bind=engine)  # Tells SQLAlchemy: “Look at all models that inherit from Base (like User) and create their tables in the database if they don’t already exist.”
# When SQLAlchemy builds the metadata, it collects all the tables and models that were imported.

# Opens a session (like opening a conversation with the database).
# You use this session to add, read, update, and delete rows.
session = SessionLocal()
# Out:
# 2025-09-20 22:05:56,649 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-09-20 22:05:56,653 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,656 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-09-20 22:05:56,656 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,658 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-09-20 22:05:56,658 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,663 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:56,667 INFO sqlalchemy.engine.Engine DESCRIBE `sqlalchemy_basics`.`users`
# 2025-09-20 22:05:56,671 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,676 INFO sqlalchemy.engine.Engine DESCRIBE `sqlalchemy_basics`.`posts`
# 2025-09-20 22:05:56,676 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,682 INFO sqlalchemy.engine.Engine DESCRIBE `sqlalchemy_basics`.`profiles`
# 2025-09-20 22:05:56,685 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,689 INFO sqlalchemy.engine.Engine DESCRIBE `sqlalchemy_basics`.`likes`
# 2025-09-20 22:05:56,690 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,694 INFO sqlalchemy.engine.Engine
# DROP TABLE likes
# 2025-09-20 22:05:56,695 INFO sqlalchemy.engine.Engine [no key 0.00176s] {}
# 2025-09-20 22:05:56,730 INFO sqlalchemy.engine.Engine
# DROP TABLE profiles
# 2025-09-20 22:05:56,732 INFO sqlalchemy.engine.Engine [no key 0.00184s] {}
# 2025-09-20 22:05:56,766 INFO sqlalchemy.engine.Engine
# DROP TABLE posts
# 2025-09-20 22:05:56,767 INFO sqlalchemy.engine.Engine [no key 0.00110s] {}
# 2025-09-20 22:05:56,795 INFO sqlalchemy.engine.Engine
# DROP TABLE users
# 2025-09-20 22:05:56,798 INFO sqlalchemy.engine.Engine [no key 0.00352s] {}
# 2025-09-20 22:05:56,830 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:56,835 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:56,835 INFO sqlalchemy.engine.Engine DESCRIBE `sqlalchemy_basics`.`users`
# 2025-09-20 22:05:56,836 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,838 INFO sqlalchemy.engine.Engine DESCRIBE `sqlalchemy_basics`.`posts`
# 2025-09-20 22:05:56,839 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,840 INFO sqlalchemy.engine.Engine DESCRIBE `sqlalchemy_basics`.`profiles`
# 2025-09-20 22:05:56,840 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,842 INFO sqlalchemy.engine.Engine DESCRIBE `sqlalchemy_basics`.`likes`
# 2025-09-20 22:05:56,842 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-20 22:05:56,844 INFO sqlalchemy.engine.Engine
# CREATE TABLE users (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	username VARCHAR(50) NOT NULL,
# 	email VARCHAR(100) NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-09-20 22:05:56,846 INFO sqlalchemy.engine.Engine [no key 0.00229s] {}
# 2025-09-20 22:05:56,883 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_users_username ON users (username)
# 2025-09-20 22:05:56,884 INFO sqlalchemy.engine.Engine [no key 0.00139s] {}
# 2025-09-20 22:05:56,911 INFO sqlalchemy.engine.Engine CREATE INDEX ix_users_id ON users (id)
# 2025-09-20 22:05:56,913 INFO sqlalchemy.engine.Engine [no key 0.00270s] {}
# 2025-09-20 22:05:56,943 INFO sqlalchemy.engine.Engine CREATE UNIQUE INDEX ix_users_email ON users (email)
# 2025-09-20 22:05:56,944 INFO sqlalchemy.engine.Engine [no key 0.00068s] {}
# 2025-09-20 22:05:56,979 INFO sqlalchemy.engine.Engine
# CREATE TABLE posts (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	title VARCHAR(100) NOT NULL,
# 	content TEXT NOT NULL,
# 	user_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(user_id) REFERENCES users (id) ON DELETE CASCADE ON UPDATE CASCADE
# )
#
#
# 2025-09-20 22:05:56,981 INFO sqlalchemy.engine.Engine [no key 0.00222s] {}
# 2025-09-20 22:05:57,034 INFO sqlalchemy.engine.Engine CREATE INDEX ix_posts_id ON posts (id)
# 2025-09-20 22:05:57,038 INFO sqlalchemy.engine.Engine [no key 0.00420s] {}
# 2025-09-20 22:05:57,069 INFO sqlalchemy.engine.Engine CREATE INDEX ix_posts_title ON posts (title)
# 2025-09-20 22:05:57,070 INFO sqlalchemy.engine.Engine [no key 0.00104s] {}
# 2025-09-20 22:05:57,104 INFO sqlalchemy.engine.Engine
# CREATE TABLE profiles (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	bio TEXT,
# 	user_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	UNIQUE (user_id),
# 	FOREIGN KEY(user_id) REFERENCES users (id) ON DELETE CASCADE ON UPDATE CASCADE
# )
#
#
# 2025-09-20 22:05:57,105 INFO sqlalchemy.engine.Engine [no key 0.00089s] {}
# 2025-09-20 22:05:57,158 INFO sqlalchemy.engine.Engine CREATE INDEX ix_profiles_id ON profiles (id)
# 2025-09-20 22:05:57,159 INFO sqlalchemy.engine.Engine [no key 0.00072s] {}
# 2025-09-20 22:05:57,185 INFO sqlalchemy.engine.Engine
# CREATE TABLE likes (
# 	user_id INTEGER NOT NULL,
# 	post_id INTEGER NOT NULL,
# 	PRIMARY KEY (user_id, post_id),
# 	FOREIGN KEY(user_id) REFERENCES users (id) ON DELETE CASCADE ON UPDATE CASCADE,
# 	FOREIGN KEY(post_id) REFERENCES posts (id) ON DELETE CASCADE ON UPDATE CASCADE
# )
#
#
# 2025-09-20 22:05:57,186 INFO sqlalchemy.engine.Engine [no key 0.00075s] {}
# 2025-09-20 22:05:57,232 INFO sqlalchemy.engine.Engine COMMIT

# %%
## CREATE

# add multiple users at once

user_john = User(username="john", email="john@example.com")
user_alice = User(username="alice", email="alice@example.com")
user_mark = User(username="mark", email="mark@example.com")
session.add_all([user_john, user_alice, user_mark])  # Marks it to be added.
session.commit()  # Actually saves it in the database.

# add a single user

new_user = User(username="islam", email="islam@example.com")
session.add(new_user)  # Marks it to be added.
session.commit()  # Actually saves it in the database.
session.refresh(new_user)  # Updates the Python object with fresh data from the DB (like its auto-generated id).
print("Inserted:", new_user.id, new_user.username)

users = session.query(User).all() 
for user in users:
    post = Post(title=f"Post by {user.username}", content=f"A post by {user.username}", user_id=user.id)
    session.add(post)
    session.commit()
# Out:
# 2025-09-20 22:05:57,292 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:57,297 INFO sqlalchemy.engine.Engine INSERT INTO users (username, email) VALUES (%(username)s, %(email)s)
# 2025-09-20 22:05:57,300 INFO sqlalchemy.engine.Engine [generated in 0.00239s] {'username': 'john', 'email': 'john@example.com'}
# 2025-09-20 22:05:57,305 INFO sqlalchemy.engine.Engine INSERT INTO users (username, email) VALUES (%(username)s, %(email)s)
# 2025-09-20 22:05:57,308 INFO sqlalchemy.engine.Engine [cached since 0.01072s ago] {'username': 'alice', 'email': 'alice@example.com'}
# 2025-09-20 22:05:57,313 INFO sqlalchemy.engine.Engine INSERT INTO users (username, email) VALUES (%(username)s, %(email)s)
# 2025-09-20 22:05:57,318 INFO sqlalchemy.engine.Engine [cached since 0.02021s ago] {'username': 'mark', 'email': 'mark@example.com'}
# 2025-09-20 22:05:57,326 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:57,338 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:57,339 INFO sqlalchemy.engine.Engine INSERT INTO users (username, email) VALUES (%(username)s, %(email)s)
# 2025-09-20 22:05:57,339 INFO sqlalchemy.engine.Engine [cached since 0.04219s ago] {'username': 'islam', 'email': 'islam@example.com'}
# 2025-09-20 22:05:57,341 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:57,351 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:57,360 INFO sqlalchemy.engine.Engine SELECT users.id, users.username, users.email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:57,364 INFO sqlalchemy.engine.Engine [generated in 0.00360s] {'pk_1': 4}
# Inserted: 4 islam
# 2025-09-20 22:05:57,369 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# 2025-09-20 22:05:57,372 INFO sqlalchemy.engine.Engine [generated in 0.00274s] {}
# 2025-09-20 22:05:57,377 INFO sqlalchemy.engine.Engine INSERT INTO posts (title, content, user_id) VALUES (%(title)s, %(content)s, %(user_id)s)
# 2025-09-20 22:05:57,380 INFO sqlalchemy.engine.Engine [generated in 0.00351s] {'title': 'Post by john', 'content': 'A post by john', 'user_id': 1}
# 2025-09-20 22:05:57,384 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:57,396 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:57,400 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:57,402 INFO sqlalchemy.engine.Engine [generated in 0.00250s] {'pk_1': 2}
# 2025-09-20 22:05:57,405 INFO sqlalchemy.engine.Engine INSERT INTO posts (title, content, user_id) VALUES (%(title)s, %(content)s, %(user_id)s)
# 2025-09-20 22:05:57,409 INFO sqlalchemy.engine.Engine [cached since 0.03205s ago] {'title': 'Post by alice', 'content': 'A post by alice', 'user_id': 2}
# 2025-09-20 22:05:57,414 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:57,429 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:57,431 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:57,435 INFO sqlalchemy.engine.Engine [cached since 0.03476s ago] {'pk_1': 3}
# 2025-09-20 22:05:57,441 INFO sqlalchemy.engine.Engine INSERT INTO posts (title, content, user_id) VALUES (%(title)s, %(content)s, %(user_id)s)
# 2025-09-20 22:05:57,448 INFO sqlalchemy.engine.Engine [cached since 0.07116s ago] {'title': 'Post by mark', 'content': 'A post by mark', 'user_id': 3}
# 2025-09-20 22:05:57,456 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:57,467 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:57,471 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:57,472 INFO sqlalchemy.engine.Engine [cached since 0.07245s ago] {'pk_1': 4}
# 2025-09-20 22:05:57,474 INFO sqlalchemy.engine.Engine INSERT INTO posts (title, content, user_id) VALUES (%(title)s, %(content)s, %(user_id)s)
# 2025-09-20 22:05:57,475 INFO sqlalchemy.engine.Engine [cached since 0.09825s ago] {'title': 'Post by islam', 'content': 'A post by islam', 'user_id': 4}
# 2025-09-20 22:05:57,477 INFO sqlalchemy.engine.Engine COMMIT

# %%
## UPDATE

user = session.query(User).filter(User.username == "alice").first()  # Finds the user with username 'alice'.
user.email = "alice@new.com"  # Change the email in Python memory.
session.commit()  # Pushes the update into the database.
session.refresh(user)  # Refreshes the object from the DB (so it’s up-to-date).
print("Updated:", user)
# Out:
# 2025-09-20 22:05:57,508 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:57,521 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.username = %(username_1)s
#  LIMIT %(param_1)s
# 2025-09-20 22:05:57,530 INFO sqlalchemy.engine.Engine [generated in 0.00896s] {'username_1': 'alice', 'param_1': 1}
# 2025-09-20 22:05:57,540 INFO sqlalchemy.engine.Engine UPDATE users SET email=%(email)s WHERE users.id = %(users_id)s
# 2025-09-20 22:05:57,541 INFO sqlalchemy.engine.Engine [generated in 0.00141s] {'email': 'alice@new.com', 'users_id': 2}
# 2025-09-20 22:05:57,544 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:57,560 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:57,570 INFO sqlalchemy.engine.Engine SELECT users.id, users.username, users.email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:57,572 INFO sqlalchemy.engine.Engine [cached since 0.2124s ago] {'pk_1': 2}
# Updated: <User(id=2, username=alice, email=alice@new.com)>

# %%
## DELETE

session.delete(user)  # Marks this row for deletion.
session.commit()  # Executes the deletion in the DB.
print("User Deleted.")
# Out:
# 2025-09-20 22:05:57,633 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# WHERE %(param_1)s = posts.user_id
# 2025-09-20 22:05:57,638 INFO sqlalchemy.engine.Engine [generated in 0.00490s] {'param_1': 2}
# 2025-09-20 22:05:57,650 INFO sqlalchemy.engine.Engine SELECT profiles.id AS profiles_id, profiles.bio AS profiles_bio, profiles.user_id AS profiles_user_id
# FROM profiles
# WHERE %(param_1)s = profiles.user_id
# 2025-09-20 22:05:57,655 INFO sqlalchemy.engine.Engine [generated in 0.00532s] {'param_1': 2}
# 2025-09-20 22:05:57,674 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts, likes
# WHERE %(param_1)s = likes.user_id AND posts.id = likes.post_id
# 2025-09-20 22:05:57,676 INFO sqlalchemy.engine.Engine [generated in 0.00220s] {'param_1': 2}
# 2025-09-20 22:05:57,700 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users, likes
# WHERE %(param_1)s = likes.post_id AND users.id = likes.user_id
# 2025-09-20 22:05:57,709 INFO sqlalchemy.engine.Engine [generated in 0.00941s] {'param_1': 2}
# 2025-09-20 22:05:57,737 INFO sqlalchemy.engine.Engine DELETE FROM posts WHERE posts.id = %(id)s
# 2025-09-20 22:05:57,743 INFO sqlalchemy.engine.Engine [generated in 0.01112s] {'id': 2}
# 2025-09-20 22:05:57,754 INFO sqlalchemy.engine.Engine DELETE FROM users WHERE users.id = %(id)s
# 2025-09-20 22:05:57,758 INFO sqlalchemy.engine.Engine [generated in 0.00328s] {'id': 2}
# 2025-09-20 22:05:57,771 INFO sqlalchemy.engine.Engine COMMIT
# User Deleted.

# %%
## READ all users with filtering and ordering

# Filter_by: Only works with simple equality checks (=), You pass the field name directly as a keyword argument.        
users = session.query(User).all()  # get all users
first_user = session.query(User).first()  # get the first user
last_user = session.query(User).order_by(User.id.desc()).first()  # get the last user
user_by_id = session.query(User).get(2)  # get user by primary key (id=2)
user_by_username = session.query(User).filter_by(username='alice').first()  # get user by username

# Filter: More powerful → supports all conditions (==, !=, <, >, in_, like, etc.), You must use the model.field syntax.
result = session.query(User).filter(User.username == "alice").all()
result = session.query(User).filter(User.id > 5).all()
result = session.query(User).filter(and_(User.id > 5, User.username != "bob")).all()
result = session.query(User).filter(or_(User.username == "alice", User.username == "bob")).all()
result = session.query(User).filter(User.username.like("%a%")).all()
result = session.query(User).filter(User.email.contains("@gmail.com")).all()
result = session.query(User).filter(User.username.startswith("a")).all()
result = session.query(User).filter(User.username.endswith("z")).all()

# Ordering and Pagination
result = session.query(User).order_by(User.username).all()
result = session.query(User).order_by(User.id.desc()).all()
session.query(User).limit(5).all()     # first 5 users
session.query(User).offset(10).all()  # skip first 10 users

# Count
result = session.query(User).count()  # total number of users
print(result)

# Selecting Only Some Columns
result = session.query(User.username, User.email).all()  # list of tuples (username, email)

# Selecting Distinct Values
result = session.query(User.username).distinct().all()  # unique usernames

# Combining Filters = Using AND
result = session.query(User).filter(User.username == 'islam').filter(User.id > 3).all()  # username='islam' and id>3
print(result)

# IN / NOT IN
result = session.query(User).filter(User.id.in_([1, 2, 3])).all()  # id in (1, 2, 3)
result = session.query(User).filter(~User.id.in_([1, 2, 3])).all()  # id not in (1, 2, 3)

# NULL Checks
result = session.query(User).filter(User.email == None).all()  # email is NULL
result = session.query(User).filter(User.email != None).all()  # email is NOT NULL
# Out:
# 2025-09-20 22:05:57,917 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:57,921 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# 2025-09-20 22:05:57,924 INFO sqlalchemy.engine.Engine [cached since 0.5547s ago] {}
# 2025-09-20 22:05:57,936 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
#  LIMIT %(param_1)s
# 2025-09-20 22:05:57,939 INFO sqlalchemy.engine.Engine [generated in 0.00265s] {'param_1': 1}
# 2025-09-20 22:05:57,943 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users ORDER BY users.id DESC
#  LIMIT %(param_1)s
# 2025-09-20 22:05:57,949 INFO sqlalchemy.engine.Engine [generated in 0.00619s] {'param_1': 1}
# 2025-09-20 22:05:57,956 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:57,957 INFO sqlalchemy.engine.Engine [generated in 0.00111s] {'pk_1': 2}
# 2025-09-20 22:05:57,960 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.username = %(username_1)s
#  LIMIT %(param_1)s
# 2025-09-20 22:05:57,966 INFO sqlalchemy.engine.Engine [cached since 0.445s ago] {'username_1': 'alice', 'param_1': 1}
# 2025-09-20 22:05:58,066 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.username = %(username_1)s
# 2025-09-20 22:05:58,068 INFO sqlalchemy.engine.Engine [generated in 0.00185s] {'username_1': 'alice'}
# 2025-09-20 22:05:58,070 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id > %(id_1)s
# 2025-09-20 22:05:58,070 INFO sqlalchemy.engine.Engine [generated in 0.00060s] {'id_1': 5}
# 2025-09-20 22:05:58,073 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id > %(id_1)s AND users.username != %(username_1)s
# 2025-09-20 22:05:58,073 INFO sqlalchemy.engine.Engine [generated in 0.00069s] {'id_1': 5, 'username_1': 'bob'}
# 2025-09-20 22:05:58,076 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.username = %(username_1)s OR users.username = %(username_2)s
# 2025-09-20 22:05:58,077 INFO sqlalchemy.engine.Engine [generated in 0.00071s] {'username_1': 'alice', 'username_2': 'bob'}
# 2025-09-20 22:05:58,084 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.username LIKE %(username_1)s
# 2025-09-20 22:05:58,086 INFO sqlalchemy.engine.Engine [generated in 0.00202s] {'username_1': '%a%'}
# 2025-09-20 22:05:58,088 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE (users.email LIKE concat('%%', %(email_1)s, '%%'))
# 2025-09-20 22:05:58,089 INFO sqlalchemy.engine.Engine [generated in 0.00073s] {'email_1': '@gmail.com'}
# 2025-09-20 22:05:58,091 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE (users.username LIKE concat(%(username_1)s, '%%'))
# 2025-09-20 22:05:58,092 INFO sqlalchemy.engine.Engine [generated in 0.00071s] {'username_1': 'a'}
# 2025-09-20 22:05:58,096 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE (users.username LIKE concat('%%', %(username_1)s))
# 2025-09-20 22:05:58,098 INFO sqlalchemy.engine.Engine [generated in 0.00207s] {'username_1': 'z'}
# 2025-09-20 22:05:58,102 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users ORDER BY users.username
# 2025-09-20 22:05:58,103 INFO sqlalchemy.engine.Engine [generated in 0.00085s] {}
# 2025-09-20 22:05:58,106 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users ORDER BY users.id DESC
# 2025-09-20 22:05:58,107 INFO sqlalchemy.engine.Engine [generated in 0.00068s] {}
# 2025-09-20 22:05:58,108 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
#  LIMIT %(param_1)s
# 2025-09-20 22:05:58,109 INFO sqlalchemy.engine.Engine [cached since 0.1726s ago] {'param_1': 5}
# 2025-09-20 22:05:58,113 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
#  LIMIT %(param_1)s, 18446744073709551615
# 2025-09-20 22:05:58,115 INFO sqlalchemy.engine.Engine [generated in 0.00209s] {'param_1': 10}
# 2025-09-20 22:05:58,122 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users) AS anon_1
# 2025-09-20 22:05:58,123 INFO sqlalchemy.engine.Engine [generated in 0.00119s] {}
# 3
# 2025-09-20 22:05:58,127 INFO sqlalchemy.engine.Engine SELECT users.username AS users_username, users.email AS users_email
# FROM users
# 2025-09-20 22:05:58,129 INFO sqlalchemy.engine.Engine [generated in 0.00184s] {}
# 2025-09-20 22:05:58,135 INFO sqlalchemy.engine.Engine SELECT DISTINCT users.username AS users_username
# FROM users
# 2025-09-20 22:05:58,136 INFO sqlalchemy.engine.Engine [generated in 0.00105s] {}
# 2025-09-20 22:05:58,138 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.username = %(username_1)s AND users.id > %(id_1)s
# 2025-09-20 22:05:58,138 INFO sqlalchemy.engine.Engine [generated in 0.00068s] {'username_1': 'islam', 'id_1': 3}
# [<User(id=4, username=islam, email=islam@example.com)>]
# 2025-09-20 22:05:58,141 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id IN (%(id_1_1)s, %(id_1_2)s, %(id_1_3)s)
# 2025-09-20 22:05:58,141 INFO sqlalchemy.engine.Engine [generated in 0.00073s] {'id_1_1': 1, 'id_1_2': 2, 'id_1_3': 3}
# 2025-09-20 22:05:58,146 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE (users.id NOT IN (%(id_1_1)s, %(id_1_2)s, %(id_1_3)s))
# 2025-09-20 22:05:58,148 INFO sqlalchemy.engine.Engine [generated in 0.00228s] {'id_1_1': 1, 'id_1_2': 2, 'id_1_3': 3}
# 2025-09-20 22:05:58,152 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.email IS NULL
# 2025-09-20 22:05:58,153 INFO sqlalchemy.engine.Engine [generated in 0.00089s] {}
# 2025-09-20 22:05:58,155 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.email IS NOT NULL
# 2025-09-20 22:05:58,155 INFO sqlalchemy.engine.Engine [generated in 0.00062s] {}
# /tmp/ipykernel_125173/3059670997.py:7: LegacyAPIWarning: The Query.get() method is considered legacy as of the 1.x series of SQLAlchemy and becomes a legacy construct in 2.0. The method is now available as Session.get() (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   user_by_id = session.query(User).get(2)  # get user by primary key (id=2)

# %%
## One-to-Many Relationship Example

new_user = User(username='ahmed', email='ahmed@gmail.com')
session.add(new_user)
session.commit()
session.refresh(new_user)


post1 = Post(title='First Post', content='This is the first post', user_id=new_user.id, author=new_user)
post2 = Post(title='Second Post', content='This is the second post', user_id=new_user.id, author=new_user)
session.add_all([post1, post2])
session.commit()

user = session.query(User).order_by(User.id.desc()).first()
print("User:", user)
print("Posts:", user.posts)  # Access related posts via the relationship attribute.
# Out:
# 2025-09-20 22:05:59,457 INFO sqlalchemy.engine.Engine INSERT INTO users (username, email) VALUES (%(username)s, %(email)s)
# 2025-09-20 22:05:59,458 INFO sqlalchemy.engine.Engine [cached since 2.161s ago] {'username': 'ahmed', 'email': 'ahmed@gmail.com'}
# 2025-09-20 22:05:59,464 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:59,481 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,485 INFO sqlalchemy.engine.Engine SELECT users.id, users.username, users.email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,486 INFO sqlalchemy.engine.Engine [cached since 2.127s ago] {'pk_1': 5}
# 2025-09-20 22:05:59,489 INFO sqlalchemy.engine.Engine INSERT INTO posts (title, content, user_id) VALUES (%(title)s, %(content)s, %(user_id)s)
# 2025-09-20 22:05:59,490 INFO sqlalchemy.engine.Engine [cached since 2.114s ago] {'title': 'First Post', 'content': 'This is the first post', 'user_id': 5}
# 2025-09-20 22:05:59,491 INFO sqlalchemy.engine.Engine INSERT INTO posts (title, content, user_id) VALUES (%(title)s, %(content)s, %(user_id)s)
# 2025-09-20 22:05:59,493 INFO sqlalchemy.engine.Engine [cached since 2.116s ago] {'title': 'Second Post', 'content': 'This is the second post', 'user_id': 5}
# 2025-09-20 22:05:59,498 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:59,508 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,509 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users ORDER BY users.id DESC
#  LIMIT %(param_1)s
# 2025-09-20 22:05:59,512 INFO sqlalchemy.engine.Engine [cached since 1.569s ago] {'param_1': 1}
# User: <User(id=5, username=ahmed, email=ahmed@gmail.com)>
# 2025-09-20 22:05:59,515 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# WHERE %(param_1)s = posts.user_id
# 2025-09-20 22:05:59,516 INFO sqlalchemy.engine.Engine [cached since 1.884s ago] {'param_1': 5}
# Posts: [<Post(id=5, title=First Post, user_id=5)>, <Post(id=6, title=Second Post, user_id=5)>]

# %%
## One-to-One Relationship Example
users = session.query(User).all()

for user in users:
    profile = Profile(bio=f"Hello, I'm {user.username}!", user_id=user.id, user=user)
    session.add(profile)
    session.commit()
    
print("profiles added")
# Out:
# 2025-09-20 22:05:59,529 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# 2025-09-20 22:05:59,531 INFO sqlalchemy.engine.Engine [cached since 2.161s ago] {}
# 2025-09-20 22:05:59,535 INFO sqlalchemy.engine.Engine SELECT profiles.id AS profiles_id, profiles.bio AS profiles_bio, profiles.user_id AS profiles_user_id
# FROM profiles
# WHERE %(param_1)s = profiles.user_id
# 2025-09-20 22:05:59,538 INFO sqlalchemy.engine.Engine [cached since 1.888s ago] {'param_1': 1}
# 2025-09-20 22:05:59,541 INFO sqlalchemy.engine.Engine INSERT INTO profiles (bio, user_id) VALUES (%(bio)s, %(user_id)s)
# 2025-09-20 22:05:59,543 INFO sqlalchemy.engine.Engine [generated in 0.00186s] {'bio': "Hello, I'm john!", 'user_id': 1}
# 2025-09-20 22:05:59,548 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:59,555 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,556 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,556 INFO sqlalchemy.engine.Engine [cached since 2.156s ago] {'pk_1': 3}
# 2025-09-20 22:05:59,560 INFO sqlalchemy.engine.Engine SELECT profiles.id AS profiles_id, profiles.bio AS profiles_bio, profiles.user_id AS profiles_user_id
# FROM profiles
# WHERE %(param_1)s = profiles.user_id
# 2025-09-20 22:05:59,563 INFO sqlalchemy.engine.Engine [cached since 1.913s ago] {'param_1': 3}
# 2025-09-20 22:05:59,568 INFO sqlalchemy.engine.Engine INSERT INTO profiles (bio, user_id) VALUES (%(bio)s, %(user_id)s)
# 2025-09-20 22:05:59,569 INFO sqlalchemy.engine.Engine [cached since 0.02735s ago] {'bio': "Hello, I'm mark!", 'user_id': 3}
# 2025-09-20 22:05:59,572 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:59,584 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,586 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,586 INFO sqlalchemy.engine.Engine [cached since 2.186s ago] {'pk_1': 4}
# 2025-09-20 22:05:59,589 INFO sqlalchemy.engine.Engine SELECT profiles.id AS profiles_id, profiles.bio AS profiles_bio, profiles.user_id AS profiles_user_id
# FROM profiles
# WHERE %(param_1)s = profiles.user_id
# 2025-09-20 22:05:59,591 INFO sqlalchemy.engine.Engine [cached since 1.941s ago] {'param_1': 4}
# 2025-09-20 22:05:59,595 INFO sqlalchemy.engine.Engine INSERT INTO profiles (bio, user_id) VALUES (%(bio)s, %(user_id)s)
# 2025-09-20 22:05:59,597 INFO sqlalchemy.engine.Engine [cached since 0.056s ago] {'bio': "Hello, I'm islam!", 'user_id': 4}
# 2025-09-20 22:05:59,600 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:59,611 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,618 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,620 INFO sqlalchemy.engine.Engine [cached since 2.22s ago] {'pk_1': 5}
# 2025-09-20 22:05:59,624 INFO sqlalchemy.engine.Engine SELECT profiles.id AS profiles_id, profiles.bio AS profiles_bio, profiles.user_id AS profiles_user_id
# FROM profiles
# WHERE %(param_1)s = profiles.user_id
# 2025-09-20 22:05:59,626 INFO sqlalchemy.engine.Engine [cached since 1.976s ago] {'param_1': 5}
# 2025-09-20 22:05:59,631 INFO sqlalchemy.engine.Engine INSERT INTO profiles (bio, user_id) VALUES (%(bio)s, %(user_id)s)
# 2025-09-20 22:05:59,636 INFO sqlalchemy.engine.Engine [cached since 0.09449s ago] {'bio': "Hello, I'm ahmed!", 'user_id': 5}
# 2025-09-20 22:05:59,638 INFO sqlalchemy.engine.Engine COMMIT
# profiles added

# %%
## Many-to-Many Relationship Example
for user in session.query(User).all():
    for post in session.query(Post).all():
        if post.author != user:  # A user cannot like their own post
            user.liked_posts.append(post)  # User likes the post
    session.commit()
# Out:
# 2025-09-20 22:05:59,657 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,658 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# 2025-09-20 22:05:59,662 INFO sqlalchemy.engine.Engine [cached since 2.292s ago] {}
# 2025-09-20 22:05:59,667 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# 2025-09-20 22:05:59,670 INFO sqlalchemy.engine.Engine [generated in 0.00292s] {}
# 2025-09-20 22:05:59,673 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts, likes
# WHERE %(param_1)s = likes.user_id AND posts.id = likes.post_id
# 2025-09-20 22:05:59,674 INFO sqlalchemy.engine.Engine [cached since 2.001s ago] {'param_1': 1}
# 2025-09-20 22:05:59,685 INFO sqlalchemy.engine.Engine INSERT INTO likes (user_id, post_id) VALUES (%(user_id)s, %(post_id)s)
# 2025-09-20 22:05:59,686 INFO sqlalchemy.engine.Engine [generated in 0.00090s] [{'user_id': 1, 'post_id': 6}, {'user_id': 1, 'post_id': 3}, {'user_id': 1, 'post_id': 5}, {'user_id': 1, 'post_id': 4}]
# 2025-09-20 22:05:59,689 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:59,696 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,698 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# 2025-09-20 22:05:59,700 INFO sqlalchemy.engine.Engine [cached since 0.03255s ago] {}
# 2025-09-20 22:05:59,703 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,703 INFO sqlalchemy.engine.Engine [cached since 2.303s ago] {'pk_1': 1}
# 2025-09-20 22:05:59,705 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,706 INFO sqlalchemy.engine.Engine [cached since 2.306s ago] {'pk_1': 3}
# 2025-09-20 22:05:59,707 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts, likes
# WHERE %(param_1)s = likes.user_id AND posts.id = likes.post_id
# 2025-09-20 22:05:59,708 INFO sqlalchemy.engine.Engine [cached since 2.034s ago] {'param_1': 3}
# 2025-09-20 22:05:59,712 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,714 INFO sqlalchemy.engine.Engine [cached since 2.314s ago] {'pk_1': 4}
# 2025-09-20 22:05:59,719 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,719 INFO sqlalchemy.engine.Engine [cached since 2.319s ago] {'pk_1': 5}
# 2025-09-20 22:05:59,722 INFO sqlalchemy.engine.Engine INSERT INTO likes (user_id, post_id) VALUES (%(user_id)s, %(post_id)s)
# 2025-09-20 22:05:59,722 INFO sqlalchemy.engine.Engine [cached since 0.03745s ago] [{'user_id': 3, 'post_id': 5}, {'user_id': 3, 'post_id': 1}, {'user_id': 3, 'post_id': 6}, {'user_id': 3, 'post_id': 4}]
# 2025-09-20 22:05:59,724 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:59,734 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,735 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# 2025-09-20 22:05:59,736 INFO sqlalchemy.engine.Engine [cached since 0.06854s ago] {}
# 2025-09-20 22:05:59,738 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,738 INFO sqlalchemy.engine.Engine [cached since 2.339s ago] {'pk_1': 1}
# 2025-09-20 22:05:59,740 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,741 INFO sqlalchemy.engine.Engine [cached since 2.341s ago] {'pk_1': 4}
# 2025-09-20 22:05:59,744 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts, likes
# WHERE %(param_1)s = likes.user_id AND posts.id = likes.post_id
# 2025-09-20 22:05:59,746 INFO sqlalchemy.engine.Engine [cached since 2.072s ago] {'param_1': 4}
# 2025-09-20 22:05:59,749 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,751 INFO sqlalchemy.engine.Engine [cached since 2.351s ago] {'pk_1': 3}
# 2025-09-20 22:05:59,752 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,753 INFO sqlalchemy.engine.Engine [cached since 2.353s ago] {'pk_1': 5}
# 2025-09-20 22:05:59,755 INFO sqlalchemy.engine.Engine INSERT INTO likes (user_id, post_id) VALUES (%(user_id)s, %(post_id)s)
# 2025-09-20 22:05:59,756 INFO sqlalchemy.engine.Engine [cached since 0.07115s ago] [{'user_id': 4, 'post_id': 5}, {'user_id': 4, 'post_id': 1}, {'user_id': 4, 'post_id': 6}, {'user_id': 4, 'post_id': 3}]
# 2025-09-20 22:05:59,757 INFO sqlalchemy.engine.Engine COMMIT
# 2025-09-20 22:05:59,765 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,766 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# 2025-09-20 22:05:59,768 INFO sqlalchemy.engine.Engine [cached since 0.1003s ago] {}
# 2025-09-20 22:05:59,770 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,770 INFO sqlalchemy.engine.Engine [cached since 2.37s ago] {'pk_1': 1}
# 2025-09-20 22:05:59,772 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,773 INFO sqlalchemy.engine.Engine [cached since 2.373s ago] {'pk_1': 5}
# 2025-09-20 22:05:59,774 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts, likes
# WHERE %(param_1)s = likes.user_id AND posts.id = likes.post_id
# 2025-09-20 22:05:59,775 INFO sqlalchemy.engine.Engine [cached since 2.101s ago] {'param_1': 5}
# 2025-09-20 22:05:59,778 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,780 INFO sqlalchemy.engine.Engine [cached since 2.38s ago] {'pk_1': 3}
# 2025-09-20 22:05:59,784 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users
# WHERE users.id = %(pk_1)s
# 2025-09-20 22:05:59,785 INFO sqlalchemy.engine.Engine [cached since 2.385s ago] {'pk_1': 4}
# 2025-09-20 22:05:59,787 INFO sqlalchemy.engine.Engine INSERT INTO likes (user_id, post_id) VALUES (%(user_id)s, %(post_id)s)
# 2025-09-20 22:05:59,788 INFO sqlalchemy.engine.Engine [cached since 0.1033s ago] [{'user_id': 5, 'post_id': 1}, {'user_id': 5, 'post_id': 3}, {'user_id': 5, 'post_id': 4}]
# 2025-09-20 22:05:59,790 INFO sqlalchemy.engine.Engine COMMIT

# %%
## INNER JOIN

results = session.query(User).join(Post, User.id == Post.user_id).all()  # Join User with Post where User.id matches Post.user_id ang get only the users who have posts
for user in results:
    print(f"User: {user.username}, Posts: {[post.title for post in user.posts]}")  # get user posts from the relationship

results = session.query(User, Post).join(Post, User.id == Post.user_id).all()  # Join User with Post where User.id matches Post.user_id and get user and their posts together without using the relationship
for user, post in results:
    print(f"User: {user.username}, Post: {post.title}")

results = session.query(User.email, Post.title).join(Post, User.id == Post.user_id).all()  # Join User with Post where User.id matches Post.user_id and get user email and their post title together without using the relationship
for email, title in results:
    print(f"Email: {email}, Post Title: {title}")

stmt = select(User.username, Post.title).select_from(User).join(Post, User.id == Post.user_id)  # Using select() to join User with Post and get username and post title 
results = session.execute(stmt).all()
for username, title in results:
    print(f"Username: {username}, Post Title: {title}")

stmt = select(User).join(Post, User.id == Post.user_id).where(Post.title.like('%First%')) # Using select() to join User with Post and filter posts with title containing 'First'
results = session.execute(stmt).all()
print(f"results: {results}")
# Out:
# 2025-09-20 22:05:59,814 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-20 22:05:59,818 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users INNER JOIN posts ON users.id = posts.user_id
# 2025-09-20 22:05:59,820 INFO sqlalchemy.engine.Engine [generated in 0.00203s] {}
# 2025-09-20 22:05:59,824 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# WHERE %(param_1)s = posts.user_id
# 2025-09-20 22:05:59,825 INFO sqlalchemy.engine.Engine [cached since 2.192s ago] {'param_1': 1}
# User: john, Posts: ['Post by john']
# 2025-09-20 22:05:59,831 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# WHERE %(param_1)s = posts.user_id
# 2025-09-20 22:05:59,832 INFO sqlalchemy.engine.Engine [cached since 2.199s ago] {'param_1': 3}
# User: mark, Posts: ['Post by mark']
# 2025-09-20 22:05:59,835 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# WHERE %(param_1)s = posts.user_id
# 2025-09-20 22:05:59,836 INFO sqlalchemy.engine.Engine [cached since 2.203s ago] {'param_1': 4}
# User: islam, Posts: ['Post by islam']
# 2025-09-20 22:05:59,838 INFO sqlalchemy.engine.Engine SELECT posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM posts
# WHERE %(param_1)s = posts.user_id
# 2025-09-20 22:05:59,838 INFO sqlalchemy.engine.Engine [cached since 2.206s ago] {'param_1': 5}
# User: ahmed, Posts: ['First Post', 'Second Post']
# 2025-09-20 22:05:59,841 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email, posts.id AS posts_id, posts.title AS posts_title, posts.content AS posts_content, posts.user_id AS posts_user_id
# FROM users INNER JOIN posts ON users.id = posts.user_id
# 2025-09-20 22:05:59,842 INFO sqlalchemy.engine.Engine [generated in 0.00063s] {}
# User: john, Post: Post by john
# User: mark, Post: Post by mark
# User: islam, Post: Post by islam
# User: ahmed, Post: First Post
# User: ahmed, Post: Second Post
# 2025-09-20 22:05:59,847 INFO sqlalchemy.engine.Engine SELECT users.email AS users_email, posts.title AS posts_title
# FROM users INNER JOIN posts ON users.id = posts.user_id
# 2025-09-20 22:05:59,848 INFO sqlalchemy.engine.Engine [generated in 0.00094s] {}
# Email: ahmed@gmail.com, Post Title: First Post
# Email: ahmed@gmail.com, Post Title: Second Post
# Email: islam@example.com, Post Title: Post by islam
# Email: john@example.com, Post Title: Post by john
# Email: mark@example.com, Post Title: Post by mark
# 2025-09-20 22:05:59,852 INFO sqlalchemy.engine.Engine SELECT users.username, posts.title
# FROM users INNER JOIN posts ON users.id = posts.user_id
# 2025-09-20 22:05:59,853 INFO sqlalchemy.engine.Engine [generated in 0.00083s] {}
# Username: ahmed, Post Title: First Post
# Username: ahmed, Post Title: Second Post
# Username: islam, Post Title: Post by islam
# Username: john, Post Title: Post by john
# Username: mark, Post Title: Post by mark
# 2025-09-20 22:05:59,856 INFO sqlalchemy.engine.Engine SELECT users.id, users.username, users.email
# FROM users INNER JOIN posts ON users.id = posts.user_id
# WHERE posts.title LIKE %(title_1)s
# 2025-09-20 22:05:59,856 INFO sqlalchemy.engine.Engine [generated in 0.00064s] {'title_1': '%First%'}
# results: [(<User(id=5, username=ahmed, email=ahmed@gmail.com)>,)]

# %%
## Left Join
results = session.query(User).outerjoin(Post, User.id == Post.user_id).all()  # Left Join User with Post where User.id matches Post.user_id and get all users even if they have no posts
for user in results:
    print(f"User: {user.username}, Posts: {[post.title for post in user.posts]}")  # get user posts from the relationship

# left join using select()
stmt = select(User).outerjoin(Post, User.id == Post.user_id)  # Left Join User with Post using select()
results = session.execute(stmt).scalars().all()
for user in results:
    print(user.username, [post.title for post in user.posts])
# Out:
# 2025-09-20 22:05:59,873 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.username AS users_username, users.email AS users_email
# FROM users LEFT OUTER JOIN posts ON users.id = posts.user_id
# 2025-09-20 22:05:59,874 INFO sqlalchemy.engine.Engine [generated in 0.00128s] {}
# User: john, Posts: ['Post by john']
# User: mark, Posts: ['Post by mark']
# User: islam, Posts: ['Post by islam']
# User: ahmed, Posts: ['First Post', 'Second Post']
# 2025-09-20 22:05:59,882 INFO sqlalchemy.engine.Engine SELECT users.id, users.username, users.email
# FROM users LEFT OUTER JOIN posts ON users.id = posts.user_id
# 2025-09-20 22:05:59,884 INFO sqlalchemy.engine.Engine [generated in 0.00213s] {}
# john ['Post by john']
# mark ['Post by mark']
# islam ['Post by islam']
# ahmed ['First Post', 'Second Post']
# ahmed ['First Post', 'Second Post']

# %%
## Full Outer Join (if supported by the database)

# Note: Not all databases support FULL OUTER JOIN. SQLite, for example, does not.

left = select(User.username, Post.title).select_from(User).outerjoin(Post, User.id == Post.user_id)  # Left Join User with Post
right = select(User.username, Post.title).select_from(Post).outerjoin(User, User.id == Post.user_id)  # Right Join User with Post (simulated using left join from Post side)
full_outer_join = left.union(right)  # Combine both sides to simulate FULL OUTER JOIN
results = session.execute(full_outer_join).all()
for username, title in results:
    print(f"Username: {username}, Post Title: {title}")
# Out:
# 2025-09-20 22:05:59,905 INFO sqlalchemy.engine.Engine SELECT users.username, posts.title
# FROM users LEFT OUTER JOIN posts ON users.id = posts.user_id UNION SELECT users.username, posts.title
# FROM posts LEFT OUTER JOIN users ON users.id = posts.user_id
# 2025-09-20 22:05:59,907 INFO sqlalchemy.engine.Engine [generated in 0.00172s] {}
# Username: ahmed, Post Title: First Post
# Username: ahmed, Post Title: Second Post
# Username: islam, Post Title: Post by islam
# Username: john, Post Title: Post by john
# Username: mark, Post Title: Post by mark

# %%
session.close()  # Closes the session (conversation) with the database.
# Out:
# 2025-09-20 22:05:59,934 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### Notes:
#
#     1. session.flush() : "Send it to DB now, but I can still cancel later. using session.rollback() "
#     2. session.commit() : "Save it for real, permanent in DB."
#     3. session.refresh(obj) : "Reload this object from DB."
#
#     4. You can get the ID right after flush() or commit() — you don’t need refresh() for IDs.
#     5. You use refresh() only if you want the latest DB state for the object.
#
#     6. Cascading
#         - `delete-orphan`: Children deleted when detached from parent
#         - `all` cascade includes all other types `save-update, merge, refresh-expire, expunge, delete`
#
#         - One-to-many → cascade="all, delete-orphan" on parent side.
#         - One-to-one → same, but only on one side.
#         - Many-to-many → don’t use delete-orphan, only `all` on one side
#
#     7. Do we need to use both cascade options with ondelete / onupdate ?
#
#         - Best practice: Use both if you want consistent behavior in ORM and DB.
#         - cascade="all, delete-orphan" → handles ORM-side deletion when working in Python.
#         - ondelete="CASCADE" → ensures DB integrity even if something deletes the parent row outside of SQLAlchemy (like raw SQL, another app, or a migration).
#
#     8. backref vs back_populates
#
#         - back_populates → You explicitly declare the relationship on both sides, You must tell SQLAlchemy which attribute on the other model points back.
#         - backref → Shortcut: define the relationship on only one side, SQLAlchemy will auto-generate the reverse relationship for you.
